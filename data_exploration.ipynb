# %% [markdown]
# # Load data and Setup paths

# %%
from prepare_data.data_loader import load_coco_json, get_dataframes
from prepare_data.data_explorer import count_images, count_annotations, get_categories, annotations_per_image, annotation_stats

data = load_coco_json()
df_images, df_annotations = get_dataframes(data)

print("Images :", count_images(df_images))
# Out:
# Images : 500

# %%
print("Annotations :", count_annotations(df_annotations))
# Out:
# Annotations : 959

# %%
print("Catégories :", get_categories(data))
# Out:
# Catégories : ['wildfire', 'fire']

# %%
print(annotations_per_image(df_annotations).head(20))
# Out:
# image_id
# 1     1
# 2     4
# 3     1
# 4     1
# 5     2
# 6     5
# 7     5
# 8     1
# 9     1
# 10    1
# 11    2
# 12    1
# 13    4
# 14    1
# 15    1
# 16    1
# 17    2
# 18    1
# 19    1
# 20    1
# dtype: int64

# %%
print("Stats :", annotation_stats(df_annotations))
